# %%
from scripts.knn_model import *
from scripts.preprocess import load_and_preprocess_data
from scripts.knn_model import evaluate_knn

# %%
X_train, X_test, y_train, y_test = load_and_preprocess_data('../data/cars_data.csv')

# %%
accuracy, distances = evaluate_knn(X_train, y_train, X_test, y_test, window_type='radius', metric='minkowski', kernel=uniform_kernel)
print(f'Accuracy: {accuracy}')
# Out:
# Accuracy: 0.8269230769230769

# %%
plot_accuracy(X_train, y_train, X_test, y_test, max_k=20)
