# %%
import sys
sys.path.append('../scripts')
from scripts.hyperparameter_tuning import tune_hyperparameters
from scripts.preprocess import load_and_preprocess_data

# %%
X_train, X_test, y_train, y_test = load_and_preprocess_data('../data/cars_data.csv')

# %%
best_params, best_score = tune_hyperparameters(X_train, y_train)
# Out:
# Best Score: 0.8305024977960622
# Best Parameters: window_type=radius, n_neighbors=None, radius=1e-05, metric=minkowski, kernel=uniform_kernel
